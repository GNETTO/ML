# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df= df.drop(['Name','PassengerId','Ticket','Embarked','Parch','SibSp'], axis='columns')

# %%
df
# Out:
#      Survived  Pclass     Sex   Age     Fare Cabin
# 0           0       3    male  22.0   7.2500   NaN
# 1           1       1  female  38.0  71.2833   C85
# 2           1       3  female  26.0   7.9250   NaN
# 3           1       1  female  35.0  53.1000  C123
# 4           0       3    male  35.0   8.0500   NaN
# ..        ...     ...     ...   ...      ...   ...
# 886         0       2    male  27.0  13.0000   NaN
# 887         1       1  female  19.0  30.0000   B42
# 888         0       3  female   NaN  23.4500   NaN
# 889         1       1    male  26.0  30.0000  C148
# 890         0       3    male  32.0   7.7500   NaN
#
# [891 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# Fare          0
# Cabin       687
# dtype: int64

# %%
#remove missing data
for index, content in df.iterrows():
    #print(content.isnull())
    #if content.isnull():
    pass

# %%
df =df.dropna()
df.isna().sum()
df
# Out:
#      Survived  Pclass     Sex   Age     Fare        Cabin
# 1           1       1  female  38.0  71.2833          C85
# 3           1       1  female  35.0  53.1000         C123
# 6           0       1    male  54.0  51.8625          E46
# 10          1       3  female   4.0  16.7000           G6
# 11          1       1  female  58.0  26.5500         C103
# ..        ...     ...     ...   ...      ...          ...
# 871         1       1  female  47.0  52.5542          D35
# 872         0       1    male  33.0   5.0000  B51 B53 B55
# 879         1       1  female  56.0  83.1583          C50
# 887         1       1  female  19.0  30.0000          B42
# 889         1       1    male  26.0  30.0000         C148
#
# [185 rows x 6 columns]

# %%
#check constante

df_const = df == df.iloc[0]
df_const.all().sum()
# Out:
# 0

# %%
#remove constante
for col, content in df.iteritems():
    df_const = df == df.iloc[0]
    if df_const[col].all():
        df = df.drop([col], axis='columns')

# %%
df
# Out:
#      Survived  Pclass     Sex   Age     Fare        Cabin
# 1           1       1  female  38.0  71.2833          C85
# 3           1       1  female  35.0  53.1000         C123
# 6           0       1    male  54.0  51.8625          E46
# 10          1       3  female   4.0  16.7000           G6
# 11          1       1  female  58.0  26.5500         C103
# ..        ...     ...     ...   ...      ...          ...
# 871         1       1  female  47.0  52.5542          D35
# 872         0       1    male  33.0   5.0000  B51 B53 B55
# 879         1       1  female  56.0  83.1583          C50
# 887         1       1  female  19.0  30.0000          B42
# 889         1       1    male  26.0  30.0000         C148
#
# [185 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185 entries, 1 to 889
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  185 non-null    int64
#  1   Pclass    185 non-null    int64
#  2   Sex       185 non-null    object
#  3   Age       185 non-null    float64
#  4   Fare      185 non-null    float64
#  5   Cabin     185 non-null    object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 10.1+ KB

# %%
#d = df.select_dtypes(['object']).astype('category')
for col, content in df.select_dtypes(['object']).iteritems():
    df[col] = df[col].astype('category').cat.codes

df
# Out:
# <ipython-input-13-018543a6d8fc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype('category').cat.codes
#      Survived  Pclass  Sex   Age     Fare  Cabin
# 1           1       1    0  38.0  71.2833     73
# 3           1       1    0  35.0  53.1000     49
# 6           0       1    1  54.0  51.8625    118
# 10          1       3    0   4.0  16.7000    132
# 11          1       1    0  58.0  26.5500     44
# ..        ...     ...  ...   ...      ...    ...
# 871         1       1    0  47.0  52.5542     92
# 872         0       1    1  33.0   5.0000     30
# 879         1       1    0  56.0  83.1583     62
# 887         1       1    0  19.0  30.0000     26
# 889         1       1    1  26.0  30.0000     53
#
# ...

# %%
df= df.drop(['Cabin'], axis='columns')
df
# Out:
#      Survived  Pclass  Sex   Age     Fare
# 1           1       1    0  38.0  71.2833
# 3           1       1    0  35.0  53.1000
# 6           0       1    1  54.0  51.8625
# 10          1       3    0   4.0  16.7000
# 11          1       1    0  58.0  26.5500
# ..        ...     ...  ...   ...      ...
# 871         1       1    0  47.0  52.5542
# 872         0       1    1  33.0   5.0000
# 879         1       1    0  56.0  83.1583
# 887         1       1    0  19.0  30.0000
# 889         1       1    1  26.0  30.0000
#
# [185 rows x 5 columns]

# %%
Y = df.Survived
X = df.drop(['Survived'],axis='columns')

# %%
#plt.scatter(df.Age, df.Survived)

# %%
tree = DecisionTreeClassifier()
tree.fit(X,Y)
tree.predict([[1,0,38.0]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-b74e710243ab> in <module>
#       1 tree = DecisionTreeClassifier()
#       2 tree.fit(X,Y)
# ----> 3 tree.predict([[1,0,38.0]])
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in predict(self, X, check_input)
#     435         """
#     436         check_is_fitted(self)
# --> 437         X = self._validate_X_predict(X, check_input)
#     438         proba = self.tree_.predict(X)
#     439         n_samples = X.shape[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in _validate_X_predict(self, X, check_input)
#     400         """Validate the training data on predict (probabilities)."""
#     401         if check_input:
# --> 402             X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr",
#     403                                     reset=False)
# ...

# %%
tree.predict([[1,1,26.0]])

# %%
tree.predict([[1,1,33.0]])

# %%
tree.predict([[3,0,4.0]])

# %%
tree.score(X,Y)
